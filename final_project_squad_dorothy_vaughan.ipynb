# %% [markdown]
# <a href="https://colab.research.google.com/github/polydiaguiar/DataAnalysis-AcademicPerformance/blob/main/final_project_squad_dorothy_vaughan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ☑ Libraries and dataset' imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

caminho = '/content/drive/MyDrive/bancos/student_habits_performance.csv'
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(caminho)

# %% [markdown]
# # 🔍 Data wraggling

# %%
data = df.copy()

# %%
data.shape
# Out:
# (1000, 16)

# %%
data.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
info = pd.DataFrame({'Columns':data.columns,
                     'Type': data.dtypes,
                     'NaN': data.isna().sum(),
                     '%NaN': (data.isna().sum()/len(data))*100,
                     'Values unique for feature': data.nunique()
})

info
# Out:
#                                                      Columns     Type  NaN  \
# student_id                                        student_id   object    0
# age                                                      age    int64    0
# gender                                                gender   object    0
# study_hours_per_day                      study_hours_per_day  float64    0
# social_media_hours                        social_media_hours  float64    0
# netflix_hours                                  netflix_hours  float64    0
# part_time_job                                  part_time_job   object    0
# attendance_percentage                  attendance_percentage  float64    0
# sleep_hours                                      sleep_hours  float64    0
# diet_quality                                    diet_quality   object    0
# exercise_frequency                        exercise_frequency    int64    0
# ...

# %%
# Create a barplot using the counts
sns.barplot(
    x=data['parental_education_level'].value_counts().index,
    y=data['parental_education_level'].value_counts().values
)
# Out:
# <Axes: xlabel='parental_education_level'>
